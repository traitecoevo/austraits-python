# %% [markdown]
# # Download _austraits_ data in python
# by: J.R. Ferrer-Paris [@jrfep](https://github.com/jrfep)
#
# We will download data from [AusTraits](https://austraits.org/) ([pre-print](https://www.biorxiv.org/content/10.1101/2021.01.04.425314v1)) in a local folder.

# %% [markdown]
# ## Libraries
# Let's start loading the libraries

# %%
from pathlib import Path
import os
import json
import urllib
from zipfile import ZipFile

# %% [markdown]
# ## Read _austraits_ data
# We will download the file from the [Zenodo repository](https://zenodo.org/record/5112001) using the API url and saving this under the data folder.

# %%
repodir = Path("../") 
outputdir = repodir / "data/austraits/"

if not os.path.isdir(outputdir):
    os.makedirs(outputdir)

# %% [markdown]
# We use urllib to open the url and read the data (if successfully connected!), we write this as a function:

# %%
def getResponse(url):
    operUrl = urllib.request.urlopen(url)
    if(operUrl.getcode()==200):
       data = operUrl.read()
    else:
       print("Error receiving data", operUrl.getcode())
    return data

# %% [markdown]
# Now we need to select the right `url` for the master version of the repositoy. This should always point to the latest version of the data.

# %%
dataset = "https://zenodo.org/api/records/3568417"

# %% [markdown]
# Now we run the function `getResponse` and save the results as an object `zrecord`:

# %%
zrecord = getResponse(dataset)

# %% [markdown]
# Response data is in json format, need to parse it:

# %%
jsonData = json.loads(zrecord)

# %%
jsonData
# Out:
# {'conceptdoi': '10.5281/zenodo.3568417',
#  'conceptrecid': '3568417',
#  'created': '2021-07-18T06:32:30.575319+00:00',
#  'doi': '10.5281/zenodo.5112001',
#  'files': [{'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:cd7ba1c395b976a02fd4c3c772d88d78',
#    'key': 'austraits-3.0.2.rds',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/austraits-3.0.2.rds'},
#    'size': 12325324,
#    'type': 'rds'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:ed44176eb71466fe9a4ca1773d6b5961',
#    'key': 'austraits-3.0.2.zip',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/austraits-3.0.2.zip'},
#    'size': 14738862,
#    'type': 'zip'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:7047ae5b30b1727140000a4daa484722',
#    'key': 'dictionary.html',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/dictionary.html'},
#    'size': 1677858,
#    'type': 'html'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:483881222a0c9635ba01b3f0d802730f',
#    'key': 'NEWS.md',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/NEWS.md'},
#    'size': 37782,
#    'type': 'md'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:eaee76500f89c73dc515f233a9f6053d',
#    'key': 'readme.txt',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/readme.txt'},
#    'size': 9904,
#    'type': 'txt'}],
#  'id': 5112001,
#  'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5112001.svg',
#   'bucket': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022',
#   'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.3568417.svg',
#   'conceptdoi': 'https://doi.org/10.5281/zenodo.3568417',
#   'doi': 'https://doi.org/10.5281/zenodo.5112001',
#   'html': 'https://zenodo.org/record/5112001',
#   'latest': 'https://zenodo.org/api/records/5112001',
#   'latest_html': 'https://zenodo.org/record/5112001',
#   'self': 'https://zenodo.org/api/records/5112001'},
#  'metadata': {'access_right': 'open',
#   'access_right_category': 'success',
#   'communities': [{'id': 'austraits'}],
#   'contributors': [{'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Sauquet, Hervé',
#     'orcid': '0000-0001-8305-3236',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Wright, Ian J.',
#     'orcid': '0000-0001-8338-9143',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Indiarto, Dony',
#     'orcid': '0000-0001-9546-8201',
#     'type': 'ProjectMember'},
#    {'affiliation': 'CSIRO',
#     'name': 'Andrew, Sam',
#     'orcid': '0000-0003-4589-2746',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Baxter, Caitlan',
#     'type': 'ProjectMember'},
#    {'affiliation': 'NSW Department of Primary Industries',
#     'name': 'Lawson, James',
#     'orcid': '0000-0001-7983-4443',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Allen, Stuart',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Fuchs, Anne',
#     'orcid': '0000-0001-5737-8803',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Monro, Anna',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Kar, Fonti',
#     'orcid': '0000-0002-2760-3974',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Swinburne University of Technology',
#     'name': 'Adams, Mark A',
#     'orcid': '0000-0002-8154-0097',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Ahrens, Collin W.',
#     'orcid': '0000-0002-0614-9928',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Alfonzetti, Matthew',
#     'orcid': '0000-0002-0064-6368',
#     'type': 'DataCollector'},
#    {'name': 'Amini, Sophia', 'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Angevin, Tara',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Rainforest Studies, School for Field Studies, Yungaburra, Queensland',
#     'name': 'Apgaua, Deborah M.G.',
#     'orcid': '0000-0002-6303-6989',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Arndt, Stefan',
#     'orcid': '0000-0001-7086-9375',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Ash, Julian',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Atkin, Owen K.',
#     'orcid': '0000-0003-1041-5202',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Atkinson, Joe',
#     'orcid': '0000-0001-9232-4421',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Auld, Tony',
#     'orcid': '0000-0002-8766-2829',
#     'type': 'DataCollector'},
#    {'affiliation': 'Southern Cross University',
#     'name': 'Baker, Andrew',
#     'orcid': '0000-0002-0658-3767',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Vienna',
#     'name': 'Balthazar, Maria von',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland Herbarium',
#     'name': 'Bean, Anthony',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Blackman, Chris J.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Imperial College',
#     'name': 'Bloomfield, Keith',
#     'type': 'DataCollector'},
#    {'name': 'Boreham, Tara', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Bowman, David M. J. S.',
#     'orcid': '0000-0001-8075-124X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Wollongong',
#     'name': 'Bradstock, Ross',
#     'orcid': '0000-0002-6904-2394',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian Institute of Botanical Science, Royal Botanic Gardens and Domain Trust',
#     'name': 'Bragg, Jason',
#     'orcid': '0000-0002-7621-7295',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry, Germany',
#     'name': 'Brand, Willi A.',
#     'type': 'DataCollector'},
#    {'name': 'Briggs, Amber', 'type': 'DataCollector'},
#    {'name': 'Brock, John', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Brodribb, Timothy J.',
#     'orcid': '0000-0002-4964-6107',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Buckton, Genevieve',
#     'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Burrows, Geoff',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Butler, Don',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Caldwell, Elizabeth',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Melbourne',
#     'name': 'Camac, James',
#     'orcid': '0000-0003-4785-0742',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Carpenter, Raymond',
#     'orcid': '0000-0001-7129-2870',
#     'type': 'DataCollector'},
#    {'affiliation': "King's College London",
#     'name': 'Catford, Jane A.',
#     'orcid': '0000-0003-0582-5960',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Cawthray, Gregory R.',
#     'orcid': '0000-0003-1150-6675',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Cernusak, Lucas A.',
#     'orcid': '0000-0002-7575-5526',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Agriculture, Australia',
#     'name': 'Chandler, Gregory',
#     'orcid': '0000-0002-0905-6823',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium',
#     'name': 'Chapman, Alex R.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Federation University',
#     'name': 'Cheal, David',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Cheesman, Alexander W.',
#     'orcid': '0000-0003-3931-5766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Chen, Si-Chong',
#     'orcid': '0000-0002-6855-2595',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Chinnock, Robert',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Choat, Brendan',
#     'orcid': '0000-0002-9105-640X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Clarke, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Clayton, Derek',
#     'type': 'DataCollector'},
#    {'affiliation': 'Brooklyn Botanic Garden',
#     'name': 'Clemants, Steven',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Clifford, Harold Trevor',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Clinton, Brook',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Clode, Peta L.',
#     'orcid': '0000-0002-5188-4737',
#     'type': 'DataCollector'},
#    {'name': 'Cochrane, Michelle', 'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium',
#     'name': 'Coleman, Helen',
#     'type': 'DataCollector'},
#    {'name': 'Collins, Bronwyn', 'type': 'DataCollector'},
#    {'name': 'Conti, Alessandro', 'type': 'DataCollector'},
#    {'name': 'Cooper, Wendy', 'type': 'DataCollector'},
#    {'name': 'Cooper, William', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Cornwell, William K.',
#     'orcid': '0000-0003-4080-4073',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Cosgrove, Meredith',
#     'type': 'DataCollector'},
#    {'affiliation': 'Northern Territory Herbarium',
#     'name': 'Cowie, Ian',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian National Herbarium',
#     'name': 'Craven, Lyn',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Crisp, Michael',
#     'orcid': '0000-0002-8255-6349',
#     'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Cross, Erika',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Crous, Kristine Y.',
#     'orcid': '0000-0001-9478-7593',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Cunningham, Saul',
#     'orcid': '0000-0003-0703-6893',
#     'type': 'DataCollector'},
#    {'affiliation': 'Lincoln University',
#     'name': 'Curran, Timothy',
#     'orcid': '0000-0001-8817-4360',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Curtis, Ellen',
#     'type': 'DataCollector'},
#    {'name': 'Davidson, Ian', 'type': 'DataCollector'},
#    {'affiliation': 'Environment Department, Alcoa of Australia',
#     'name': 'Daws, Matthew I.',
#     'orcid': '0000-0002-9120-4724',
#     'type': 'DataCollector'},
#    {'affiliation': 'Tasmanian Herbarium',
#     'name': 'de Salas, Miguel',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Liege',
#     'name': 'de Tombeur, Félix',
#     'orcid': '0000-0002-6012-8458',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'DeGabriel, Jane L.',
#     'orcid': '0000-0003-1245-5291',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Denton, Matthew D.',
#     'orcid': '0000-0002-2804-0384',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Dong, Ning',
#     'orcid': '0000-0003-0793-8854',
#     'type': 'DataCollector'},
#    {'affiliation': 'Lanzhou University',
#     'name': 'Du, Pengzhen',
#     'type': 'DataCollector'},
#    {'affiliation': 'Guizhou University',
#     'name': 'Duan, Honglang',
#     'orcid': '0000-0003-3761-6936',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Duncan, David H.',
#     'orcid': '0000-0003-4411-8214',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canberra',
#     'name': 'Duncan, Richard P.',
#     'orcid': '0000-0003-2295-449X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Duretto, Marco',
#     'orcid': '0000-0003-1013-4291',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Dwyer, John M.',
#     'orcid': '0000-0001-7389-5528',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney, Australia',
#     'name': 'Eamus, Derek',
#     'orcid': '0000-0003-2765-8040',
#     'type': 'DataCollector'},
#    {'affiliation': 'Melbourne Water',
#     'name': 'Edwards, Cheryl',
#     'type': 'DataCollector'},
#    {'affiliation': 'Conservation Commission of the Northern Territory',
#     'name': 'Egan, Judy',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Esperon-Rodriguez, Manuel',
#     'orcid': '0000-0003-3649-2134',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Evans, John R.',
#     'orcid': '0000-0003-1379-3532',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Everingham, Susan E.',
#     'orcid': '0000-0002-4780-2700',
#     'type': 'DataCollector'},
#    {'name': 'Fahey, Chris', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Falster, Daniel',
#     'orcid': '0000-0002-9814-092X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Farrell, Claire',
#     'orcid': '0000-0002-5822-7529',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland University of Technology',
#     'name': 'Firn, Jennifer',
#     'orcid': '0000-0001-6026-8912',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidade Federal do Rio Grande do Norte, Natal, Brazil',
#     'name': 'Fonseca, Carlos Roberto',
#     'orcid': '0000-0003-0292-0399',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland Herbarium, Australia',
#     'name': 'Forster, Paul Irwin',
#     'type': 'DataCollector'},
#    {'name': 'Foster, John', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'French, Ben J.',
#     'orcid': '0000-0001-5046-4047',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'French, Tony',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Frith, Allison',
#     'type': 'DataCollector'},
#    {'affiliation': 'Pathways Bushland and Environment Consultancy',
#     'name': 'Frood, Doug',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of California, Davis',
#     'name': 'Funk, Jennifer L.',
#     'orcid': '0000-0002-1916-5513',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gallagher, Rachael',
#     'orcid': '0000-0002-4680-8115',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Gardiner, Ronald',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Geange, Sonya R.',
#     'orcid': '0000-0001-5344-7234',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Ghannoum, Oula',
#     'orcid': '0000-0002-1341-0741',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Gill, Malcolm',
#     'type': 'DataCollector'},
#    {'affiliation': 'USDA-ARS, WMSRU',
#     'name': 'Gleason, Sean M.',
#     'orcid': '0000-0002-5607-4741',
#     'type': 'DataCollector'},
#    {'name': 'Goble-Garratt, Ethel', 'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Gosper, Carl R.',
#     'orcid': '0000-0002-0962-5117',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gray, Emma',
#     'orcid': '0000-0002-5352-0398',
#     'type': 'DataCollector'},
#    {'affiliation': 'Curtin University',
#     'name': 'Groom, Philip K.',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Grootemaat, Saskia',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Gross, Caroline',
#     'orcid': '0000-0001-8014-1548',
#     'type': 'DataCollector'},
#    {'affiliation': 'Cambridge University',
#     'name': 'Grubb, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Guerin, Greg',
#     'orcid': '0000-0002-2104-6695',
#     'type': 'DataCollector'},
#    {'affiliation': 'Massachusetts Institute of Technology',
#     'name': 'Guilherme Pereira, Caio',
#     'orcid': '0000-0003-3288-8553',
#     'type': 'DataCollector'},
#    {'name': 'Guinane, Chris', 'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Guja, Lydia',
#     'orcid': '0000-0001-5945-438X',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Melbourne',
#     'name': 'Hahs, Amy K.',
#     'orcid': '0000-0003-0163-6732',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO, Australia',
#     'name': 'Hall, TJ',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Hallet, Monique',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Harrison, Matthew Tom',
#     'orcid': '0000-0001-7425-452X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Haslehurst, Tammy',
#     'type': 'DataCollector'},
#    {'name': 'Hassiotou, Foteini', 'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Hayes, Patrick E.',
#     'orcid': '0000-0001-7554-4588',
#     'type': 'DataCollector'},
#    {'affiliation': 'Parks Australia, Department of Agriculture, Water and the Environment',
#     'name': 'Henery, Martin',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Herbohn, John',
#     'orcid': '0000-0001-5701-4882',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Hochuli, Dieter',
#     'orcid': '0000-0002-6673-4475',
#     'type': 'DataCollector'},
#    {'affiliation': 'Murdoch University',
#     'name': 'Hocking, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'Berowa NSW',
#     'name': 'Howell, Jocelyn',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Hu, Jing',
#     'type': 'DataCollector'},
#    {'affiliation': 'Nanchang Institute of Technology',
#     'name': 'Huang, Guomin',
#     'orcid': '0000-0002-7597-9386',
#     'type': 'DataCollector'},
#    {'name': 'Hughes, Kate', 'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Hughes, Lesley',
#     'orcid': '0000-0003-0313-9780',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Huisman, John',
#     'orcid': '0000-0002-5255-8423',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Ilic, Jugoslav',
#     'orcid': '0000-0001-5692-5596',
#     'type': 'DataCollector'},
#    {'name': 'Islam, Muhammad', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Jagdish, Ashika',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Jin, Daniel',
#     'orcid': '0000-0001-7492-9830',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Jordan, Gregory',
#     'orcid': '0000-0002-6033-2766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Autonoma de Nuevo Leon, Mexico',
#     'name': 'Jurado, Enrique',
#     'orcid': '0000-0002-4043-5549',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian Wildlife Conservancy',
#     'name': 'Kanowski, John',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Kasel, Sabine',
#     'orcid': '0000-0001-8188-1089',
#     'type': 'DataCollector'},
#    {'name': 'Kealley, Ian',
#     'orcid': '0000-0003-2747-3927',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, WA',
#     'name': 'Keighery, Greg',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Kellermann, Jürgen',
#     'orcid': '0000-0001-9124-9802',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Rural Fire Service',
#     'name': 'Kenny, Belinda',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Kirkpatrick, James',
#     'type': 'DataCollector'},
#    {'name': 'Knox, Kirsten', 'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Kohout, Michele',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Kooyman, Robert M.',
#     'orcid': '0000-0003-1985-9547',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Goettingen',
#     'name': 'Kotowska, Martyna M.',
#     'orcid': '0000-0002-2283-5979',
#     'type': 'DataCollector'},
#    {'name': 'Kovac, Luka', 'type': 'DataCollector'},
#    {'name': 'Kreger, Kaely',
#     'orcid': '0000-0002-5010-5797',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Kuo, John',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canterbury',
#     'name': 'Lai, Hao Ran',
#     'orcid': '0000-0001-6871-0146',
#     'type': 'DataCollector'},
#    {'affiliation': 'Université de Montréal',
#     'name': 'Laliberté, Etienne',
#     'orcid': '0000-0002-3167-2622',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Lambers, Hans',
#     'orcid': '0000-0002-4118-2272',
#     'type': 'DataCollector'},
#    {'name': 'Lambert, Martin',
#     'orcid': '0000-0003-2515-7904',
#     'type': 'DataCollector'},
#    {'affiliation': 'Curtin University',
#     'name': 'Lamont, Byron B.',
#     'orcid': '0000-0001-9279-7149',
#     'type': 'DataCollector'},
#    {'name': 'Lanceman, Dana', 'type': 'DataCollector'},
#    {'affiliation': 'Australian National University',
#     'name': 'Lanfear, Robert',
#     'orcid': '0000-0002-1140-2596',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Wyoming',
#     'name': 'Laughlin, Daniel C.',
#     'orcid': '0000-0002-9651-5732',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Laugier-Kitchener, Bree-Anne',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Laurance, Susan',
#     'orcid': '0000-0002-2831-2933',
#     'type': 'DataCollector'},
#    {'name': 'Lawes, Michael',
#     'orcid': '0000-0002-2381-6147',
#     'type': 'DataCollector'},
#    {'name': 'Laws, Claire', 'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Primary Industries',
#     'name': 'Lawson, James',
#     'orcid': '0000-0001-7983-4443',
#     'type': 'DataCollector'},
#    {'name': 'Laxton, Emma', 'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Garden Edinburgh',
#     'name': 'Lehmann, Caroline E. R.',
#     'orcid': '0000-0002-6825-124X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Leigh, Andrea',
#     'orcid': '0000-0003-3568-2606',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Leishman, Michelle R.',
#     'orcid': '0000-0003-4830-5797',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Lenz, Tanja',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Lepschi, Brendan',
#     'orcid': '0000-0002-3281-2973',
#     'type': 'DataCollector'},
#    {'affiliation': 'Fordham University',
#     'name': 'Lewis, James D.',
#     'orcid': '0000-0002-7347-9513',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Lim, Felix',
#     'orcid': '0000-0003-1227-460X',
#     'type': 'DataCollector'},
#    {'name': 'Lindsay, Liz', 'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Liu, Udayangani',
#     'orcid': '0000-0002-6192-1319',
#     'type': 'DataCollector'},
#    {'name': 'Londono, Daniel Montoya', 'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'López Martinez, Andrea',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Otago',
#     'name': 'Lord, Janice',
#     'orcid': '0000-0001-8314-0428',
#     'type': 'DataCollector'},
#    {'name': 'Ludwig, Christiane', 'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Lunt, Ian',
#     'orcid': '0000-0002-2059-899X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Waikato',
#     'name': 'Lusk, Christopher H.',
#     'orcid': '0000-0002-9037-7957',
#     'type': 'DataCollector'},
#    {'name': 'Maconochie, Mary', 'type': 'DataCollector'},
#    {'affiliation': 'University of Auckland',
#     'name': 'Macinnis-Ng, Cate',
#     'orcid': '0000-0003-3935-9814',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'McPherson, Hannah',
#     'orcid': '0000-0003-0254-4573',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'Magallón, Susana',
#     'orcid': '0000-0002-6838-7497',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Manea, Anthony',
#     'orcid': '0000-0002-0956-4529',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Marais, Karen',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Maslin, Bruce',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Mason, Riah',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Mayfield, Margaret',
#     'orcid': '0000-0002-5101-6542',
#     'type': 'DataCollector'},
#    {'affiliation': 'Biodiversity and Conservation Science, Department of Biodiversity, Conservation and Attractions, WA',
#     'name': 'Mazanec, Richard',
#     'type': 'DataCollector'},
#    {'affiliation': 'Manaaki Whenua – Landcare Research, Lincoln, New Zealand',
#     'name': 'McC Overton, Jacob',
#     'type': 'DataCollector'},
#    {'affiliation': 'Manaaki Whenua – Landcare Research, Lincoln, New Zealand',
#     'name': 'McCarthy, James K.',
#     'orcid': '0000-0003-3060-1678',
#     'type': 'DataCollector'},
#    {'name': 'McFarlane, Elissa', 'type': 'DataCollector'},
#    {'affiliation': 'Cumberland Ecology, Australia',
#     'name': 'Meers, Trevor',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water',
#     'name': 'Metcalfe, Daniel',
#     'orcid': '0000-0001-6853-7072',
#     'type': 'DataCollector'},
#    {'affiliation': 'Linkoping University',
#     'name': 'Milberg, Per',
#     'orcid': '0000-0001-6128-1051',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water',
#     'name': 'Mokany, Karel',
#     'orcid': '0000-0003-4199-3697',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Moles, Angela T.',
#     'orcid': '0000-0003-2041-7762',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Moore, Ben D.',
#     'orcid': '0000-0002-6995-4721',
#     'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Moore, Nicholas',
#     'orcid': '0000-0002-9087-7580',
#     'type': 'DataCollector'},
#    {'name': 'Morgan, Huw', 'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Morgan, John W.',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Morris, William',
#     'orcid': '0000-0002-8686-4154',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Muir, Annette',
#     'orcid': '0000-0001-9383-6613',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Munroe, Samantha',
#     'orcid': '0000-0001-7827-1028',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Myerscough, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO', 'name': 'Nelson, Des', 'type': 'DataCollector'},
#    {'name': 'Neyland, Dominic', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Nicholson, Áine',
#     'type': 'DataCollector'},
#    {'affiliation': 'Currency Creek Arboretum, Australia',
#     'name': 'Nicolle, Dean',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Nicotra, Adrienne B.',
#     'orcid': '0000-0001-6578-369X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Estonian University of Life Sciences',
#     'name': 'Niinemets, Ülo',
#     'orcid': '0000-0002-3078-2192',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'North, Tom',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canberra',
#     'name': "O'Reilly-Nugent, Andrew",
#     'orcid': '0000-0003-2071-6279',
#     'type': 'DataCollector'},
#    {'affiliation': 'Leistershire County Council, Leicester, United Kingdom',
#     'name': "O'Sullivan, Odhran S.",
#     'orcid': '0000-0002-1448-1066',
#     'type': 'DataCollector'},
#    {'affiliation': 'New College of Florida',
#     'name': 'Oberle, Brad',
#     'orcid': '0000-0002-4227-3352',
#     'type': 'DataCollector'},
#    {'name': 'Olsen, Mike', 'type': 'DataCollector'},
#    {'affiliation': 'Kyoto University',
#     'name': 'Onoda, Yusuke',
#     'orcid': '0000-0001-6245-2342',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Ooi, Mark K. J.',
#     'orcid': '0000-0002-3046-0417',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Orscheg, Corinna',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Sheffield',
#     'name': 'Osborne, Colin P.',
#     'orcid': '0000-0002-7423-3718',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Paczkowska, Grazyna',
#     'type': 'DataCollector'},
#    {'name': 'Peeters, Paula', 'type': 'DataCollector'},
#    {'affiliation': 'Istanbul Technical University',
#     'name': 'Pekin, Burak',
#     'orcid': '0000-0002-4797-6962',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Aukland',
#     'name': 'Perry, George',
#     'orcid': '0000-0001-9672-9135',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Phillips, Aaron',
#     'orcid': '0000-0002-1351-0291',
#     'type': 'DataCollector'},
#    {'affiliation': 'Griffith University',
#     'name': 'Pickering, Catherine',
#     'orcid': '0000-0002-3731-5407',
#     'type': 'DataCollector'},
#    {'affiliation': 'Greening Australia',
#     'name': 'Pickup, Melinda',
#     'orcid': '0000-0001-6118-0541',
#     'type': 'DataCollector'},
#    {'name': 'Pollitt, Loren', 'type': 'DataCollector'},
#    {'affiliation': 'McGill University',
#     'name': 'Pollock, Laura J.',
#     'orcid': '0000-0002-6004-4027',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Polmear, Rob',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Poot, Pieter',
#     'orcid': '0000-0001-7721-0696',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Possingham, Hugh',
#     'orcid': '0000-0001-7755-996X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Powell, Jeff R.',
#     'orcid': '0000-0003-1091-2452',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Power, Sally A.',
#     'orcid': '0000-0002-2723-8671',
#     'type': 'DataCollector'},
#    {'affiliation': 'Imperial College, London',
#     'name': 'Prentice, Iain Colin',
#     'orcid': '0000-0002-1296-6764',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Price, Aina',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Prior, Lynda',
#     'orcid': '0000-0002-5511-2320',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water, Australia',
#     'name': 'Prober, Suzanne M.',
#     'orcid': '0000-0002-6518-239X',
#     'type': 'DataCollector'},
#    {'name': 'Pyne, Thomas', 'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Read, Jennifer',
#     'orcid': '0000-0002-4727-3482',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Reynolds, Victoria',
#     'orcid': '0000-0002-6071-9303',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Rice, Barbara',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water, Australia',
#     'name': 'Richards, Anna E.',
#     'orcid': '0000-0002-2934-5497',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Richardson, Ben',
#     'orcid': '0000-0002-6108-0572',
#     'type': 'DataCollector'},
#    {'affiliation': 'Elizabeth Macarthur Agricultural Institute, NSW Department of Primary Industries',
#     'name': 'Rigg, Jessica L.',
#     'orcid': '0000-0002-0124-1645',
#     'type': 'DataCollector'},
#    {'name': 'Roberts, Bryan', 'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Roderick, Michael L.',
#     'orcid': '0000-0002-3630-7739',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'Rosell, Julieta A.',
#     'orcid': '0000-0001-5741-8027',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Rossetto, Maurizio',
#     'orcid': '0000-0002-4878-9114',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Rye, Barbara',
#     'orcid': '0000-0003-1254-5940',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Rymer, Paul D.',
#     'orcid': '0000-0003-0988-4351',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Helsinki, Helsinki Institute of Sustainability Science',
#     'name': 'Salomaa, Anna',
#     'orcid': '0000-0002-0509-4873',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Sams, Michael A.',
#     'orcid': '0000-0003-3311-4891',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Sanson, Gordon',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Sauquet, Hervé',
#     'orcid': '0000-0001-8305-3236',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Schmidt, Susanne',
#     'orcid': '0000-0001-8369-1238',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Vienna',
#     'name': 'Schöenenberger, Jürg',
#     'orcid': '0000-0001-6791-2731',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry',
#     'name': 'Schulze, Ernst-Detlef',
#     'orcid': '0000-0001-6188-9219',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry, Germany',
#     'name': 'Schulze, Inge',
#     'type': 'DataCollector'},
#    {'affiliation': 'University Hohenheim, Germany',
#     'name': 'Schulze, Waltraud',
#     'orcid': '0000-0001-9957-7245',
#     'type': 'DataCollector'},
#    {'name': 'Scott, Andrew John', 'type': 'DataCollector'},
#    {'affiliation': 'Rider University',
#     'name': 'Sendall, Kerrie',
#     'orcid': '0000-0001-6175-0954',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of the Sunshine Coast',
#     'name': 'Shapcott, Alison',
#     'type': 'DataCollector'},
#    {'name': 'Shaw, Veronica', 'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Shoo, Luke',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Sinclair, Steve',
#     'orcid': '0000-0002-4282-1021',
#     'type': 'DataCollector'},
#    {'name': 'Sjostrom, Anne', 'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Smith, Benjamin',
#     'orcid': '0000-0002-6987-5337',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Smith, Renee',
#     'type': 'DataCollector'},
#    {'affiliation': 'Bern University, Switzerland',
#     'name': 'Soliveres, Santiago',
#     'orcid': '0000-0001-9661-7192',
#     'type': 'DataCollector'},
#    {'affiliation': 'McGill University',
#     'name': 'Soper, Fiona',
#     'orcid': '0000-0002-9910-9377',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Sparrow, Ben',
#     'orcid': '0000-0003-2566-1895',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Spooner, Amanda',
#     'type': 'DataCollector'},
#    {'affiliation': 'Murdoch University',
#     'name': 'Standish, Rachel J.',
#     'orcid': '0000-0001-8118-1904',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Staples, Timothy L.',
#     'orcid': '0000-0002-8550-2661',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Stephens, Ruby',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Stewart, George',
#     'type': 'DataCollector'},
#    {'affiliation': 'Academy of Science Czech Republic',
#     'name': 'Suda, Jan',
#     'orcid': '0000-0001-8964-9153',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Szota, Christopher',
#     'orcid': '0000-0002-8837-591X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Tait, Catherine',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Taseski, Guy',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Tasker, Elizabeth',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Taylor, Daniel',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Thomas, Freya',
#     'orcid': '0000-0001-9926-6295',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Thompson, Ian',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Tissue, David T.',
#     'orcid': '0000-0002-8497-2047',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Tjoelker, Mark G.',
#     'orcid': '0000-0003-4607-5238',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Rainforest Studies, School for Field Studies, Yungaburra, Queensland',
#     'name': 'Tng, David Yue Phin',
#     'orcid': '0000-0001-5135-0922',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Toelken, Hellmut R.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Xishuangbanna Tropical Botanic Garden',
#     'name': 'Tomlinson, Kyle',
#     'orcid': '0000-0003-3039-6766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Trudgen, Malcolm',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Turner, Neil C.',
#     'orcid': '0000-0002-2982-0411',
#     'type': 'DataCollector'},
#    {'affiliation': 'Research Centre for Ecosystem Resilience, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'van der Merwe, Marlien',
#     'orcid': '0000-0003-1307-5143',
#     'type': 'DataCollector'},
#    {'affiliation': 'Wageningen University',
#     'name': 'van Langevelde, Frank',
#     'orcid': '0000-0001-8870-0797',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Veneklaas, Erik J.',
#     'orcid': '0000-0002-7030-4056',
#     'type': 'DataCollector'},
#    {'affiliation': 'Deakin University',
#     'name': 'Venn, Susanna',
#     'orcid': '0000-0002-7433-0120',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Vesk, Peter',
#     'orcid': '0000-0003-2008-7062',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Vlasveld, Carolyn',
#     'orcid': '0000-0001-6445-7067',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Vorontsova, Maria S.',
#     'orcid': '0000-0003-0899-1120',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Warren, Charles A.',
#     'orcid': '0000-0002-0788-4713',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Warwick, Nigel',
#     'orcid': '0000-0001-7009-3183',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Peradeniya',
#     'name': 'Weerasinghe, Lasantha K.',
#     'orcid': '0000-0002-5173-8000',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Wells, Jessie',
#     'orcid': '0000-0002-3555-5108',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Westman, W. E.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Westoby, Mark',
#     'orcid': '0000-0001-7690-4530',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'White, Matthew',
#     'orcid': '0000-0003-2120-0071',
#     'type': 'DataCollector'},
#    {'name': 'Williams, Erica', 'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Williams, Nicholas S. G.',
#     'orcid': '0000-0001-6291-9483',
#     'type': 'DataCollector'},
#    {'name': 'Williams, R. J.', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Willis, Kathryn',
#     'orcid': '0000-0001-7614-1027',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Wills, Jarrah',
#     'orcid': '0000-0002-0235-7690',
#     'type': 'DataCollector'},
#    {'affiliation': 'Botany Department, University of Otago, Dunedin, New Zealand',
#     'name': 'Wilson, J. Barstow',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of NSW and Royal Botanic Gardens and Domain Trust',
#     'name': 'Wilson, Peter G.',
#     'orcid': '0000-0001-8581-318X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Wright, Ian J.',
#     'orcid': '0000-0001-8338-9143',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Yates, Colin',
#     'orcid': '0000-0003-2286-8700',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria, Australia',
#     'name': 'Yen, Jian',
#     'orcid': '0000-0001-7964-923X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Miami, Coral Gables',
#     'name': 'Zanne, Amy E.',
#     'orcid': '0000-0001-6379-9452',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Zemunik, Graham',
#     'orcid': '0000-0002-6064-345X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Université de Montpellier',
#     'name': 'Ziemińska, Kasia',
#     'orcid': '0000-0001-7750-4758',
#     'type': 'DataCollector'}],
#   'creators': [{'affiliation': 'University of New South Wales',
#     'name': 'Falster, Daniel',
#     'orcid': '0000-0002-9814-092X'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gallagher, Rachael',
#     'orcid': '0000-0002-4680-8115'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Wenk, Elizabeth',
#     'orcid': '0000-0001-5640-5910'}],
#   'description': '<p><strong>INTRODUCTION</strong></p>\n\n<p>AusTraits is a transformative database, containing measurements on the traits of Australia&rsquo;s plant taxa, standardised from hundreds of disconnected primary sources. So far, data have been assembled from &gt; 250 distinct sources, describing &gt; 400 plant traits and &gt; 26,000 taxa.</p>\n\n<p>To handle the harmonising of diverse data sources, we use a reproducible workflow to implement the various changes required for each source to reformat it suitable for incorporation in AusTraits. Such changes include restructuring datasets, renaming variables, changing variable units, changing taxon names. While this repository contains the harmonised data, the raw data and code used to build the resource are also available on the project&rsquo;s GitHub repository, <a href="http://traitecoevo.github.io/austraits.build/">http://traitecoevo.github.io/austraits.build/</a>.</p>\n\n<p>Further information on the project is available in the associated publication and at the project website <a href="https://austraits.org">austraits.org</a>.</p>\n\n<blockquote>\n<p>Falster, Gallagher et al (2021) <em>AusTraits, a curated plant trait database for the Australian flora</em>. Scientific Data 8: 254, <a href="https://doi.org/10.1038/s41597-021-01006-6">https://doi.org/10.1038/s41597-021-01006-6</a></p>\n</blockquote>\n\n<p><strong>CONTRIBUTORS</strong></p>\n\n<p>The project is jointly led by Dr Daniel Falster (UNSW Sydney), Dr Rachael Gallagher (Western Sydney University), Dr Elizabeth Wenk (UNSW Sydney), and Dr Herv&eacute; Sauquet (Royal Botanic Gardens and Domain Trust Sydney), with input from &gt; 300 contributors from over &gt; 100 institutions (see full list above). The project was initiated by Dr Rachael Gallagher and Prof Ian Wright while at Macquarie University.</p>\n\n<p>We are grateful to the following institutions for contributing data Australian National Botanic Garden, Brisbane Rainforest Action and Information Network, Kew Botanic Gardens, National Herbarium of NSW, Northern Territory Herbarium, Queensland Herbarium, Western Australian Herbarium, South Australian Herbarium, State Herbarium of South Australia, Tasmanian Herbarium, Department of Environment, Land, Water and Planning, Victoria.</p>\n\n<p>AusTraits has been supported by investment from the Australian Research Data Commons (ARDC), via their &ldquo;Transformative data collections&rdquo; (<a href="https://doi.org/10.47486/TD044">https://doi.org/10.47486/TD044</a>) and &ldquo;Data Partnerships&rdquo; (<a href="https://doi.org/10.47486/DP720">https://doi.org/10.47486/DP720</a>) programs; fellowship grants from Australian Research Council to Falster (FT160100113), Gallagher (DE170100208) and Wright (FT100100910), a grant from Macquarie University to Gallagher. The ARDC is enabled by National Collaborative Research Investment Strategy (NCRIS).</p>\n\n<p><strong>ACCESSING AND USE OF DATA</strong></p>\n\n<p>The compiled AusTraits database is released under an open source licence (CC-BY), enabling re-use by the community.</p>\n\n<p>A requirement of use is that users cite the AusTraits resource paper, which includes all contributors as co-authors:</p>\n\n<blockquote>\n<p>Falster, Gallagher et al (2021) <em>AusTraits, a curated plant trait database for the Australian flora</em>. Scientific Data 8: 254, <a href="https://doi.org/10.1038/s41597-021-01006-6">https://doi.org/10.1038/s41597-021-01006-6</a></p>\n</blockquote>\n\n<p>In addition, we encourage users you to cite the original data sources, wherever possible.</p>\n\n<p>Note that under the license data may be redistributed, provided the attribution is maintained.</p>\n\n<p>The downloads below provide the data in two formats:</p>\n\n<ul>\n\t<li><code>austraits-3.0.2.zip</code>: data in plain text format (.csv, .bib, .yml files). Suitable for anyone, including those using Python.</li>\n\t<li><code>austraits-3.0.2.rds</code>: data as compressed R object. Suitable for us ...
#   'doi': '10.5281/zenodo.5112001',
#   'grants': [{'acronym': '',
#     'code': 'DE170100208',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::DE170100208'},
#     'program': 'Discovery Early Career Researcher Award',
#     'title': 'Discovery Early Career Researcher Award - Grant ID: DE170100208'},
#    {'acronym': '',
#     'code': 'FT160100113',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::FT160100113'},
#     'program': 'Future Fellowships',
#     'title': 'Future Fellowships - Grant ID: FT160100113'},
#    {'acronym': '',
#     'code': 'FT100100910',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::FT100100910'},
#     'program': 'Future Fellowships',
#     'title': 'Towards a trait-based plant ecology: new directions in leaf economics research'}],
#   'keywords': ['plant', 'trait', 'biodiversity'],
#   'language': 'eng',
#   'license': {'id': 'CC-BY-4.0'},
#   'notes': 'The AusTraits project received investment (https://doi.org/10.47486/TD044, https:// doi.org/10.47486/DP720) from the Australian Research Data Commons (ARDC). The ARDC is funded by the National Collaborative Research Infrastructure Strategy (NCRIS).',
#   'publication_date': '2021-07-14',
#   'references': ['Falster, Gallagher et al (2021) *AusTraits, a curated plant trait database for the Australian flora*. Scientific Data 8: 254, https://doi.org/10.1038/s41597-021-01006-6'],
#   'related_identifiers': [{'identifier': 'https://github.com/traitecoevo/austraits.build/tree/v3.0.2',
#     'relation': 'isCompiledBy',
#     'resource_type': 'dataset',
#     'scheme': 'url'},
#    {'identifier': '10.1101/2021.01.04.425314',
#     'relation': 'isCitedBy',
#     'resource_type': 'publication-preprint',
#     'scheme': 'doi'},
#    {'identifier': '10.1101/2021.01.04.425314',
#     'relation': 'isPartOf',
#     'resource_type': 'publication-preprint',
#     'scheme': 'doi'},
#    {'identifier': '10.1038/s41597-021-01006-6',
#     'relation': 'isCitedBy',
#     'resource_type': 'publication-article',
#     'scheme': 'doi'},
#    {'identifier': '10.1038/s41597-021-01006-6',
#     'relation': 'isPublishedIn',
#     'resource_type': 'publication-article',
#     'scheme': 'doi'},
#    {'identifier': '10.47486/DP720',
#     'relation': 'cites',
#     'resource_type': 'other',
#     'scheme': 'doi'},
#    {'identifier': '10.47486/TD044',
#     'relation': 'cites',
#     'resource_type': 'other',
#     'scheme': 'doi'},
#    {'identifier': '10.5281/zenodo.3568417',
#     'relation': 'isVersionOf',
#     'scheme': 'doi'}],
#   'relations': {'version': [{'count': 8,
#      'index': 7,
#      'is_last': True,
#      'last_child': {'pid_type': 'recid', 'pid_value': '5112001'},
#      'parent': {'pid_type': 'recid', 'pid_value': '3568417'}}]},
#   'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#   'title': 'AusTraits: a curated plant trait database for the Australian flora',
#   'version': 'v3.0.2'},
#  'owners': [18887],
#  'revision': 19,
#  'stats': {'downloads': 1799.0,
#   'unique_downloads': 1210.0,
#   'unique_views': 1463.0,
#   'version_downloads': 2071.0,
#   'version_unique_downloads': 1358.0,
#   'version_unique_views': 3019.0,
#   'version_views': 3929.0,
#   'version_volume': 23314519142.0,
#   'views': 1784.0,
#   'volume': 20596947994.0},
#  'updated': '2022-02-18T04:53:14.178881+00:00'}

# %% [markdown]
# The json data includes a list of files:

# %%
for files in jsonData['files']:
    print(files['key'])
# Out:
# austraits-3.0.2.rds
# austraits-3.0.2.zip
# dictionary.html
# NEWS.md
# readme.txt

# %% [markdown]
# We want to download the `zip` file with the `csv` files

# %%
outputfile = outputdir / jsonData['files'][1]['key']

if os.path.isfile(outputfile):
    print('File exists')
else:
    resp = getResponse(jsonData['files'][1]['links']['self'])
    output = open(outputfile,'wb')
    output.write(resp)
    output.close()

# %% [markdown]
# We can list the contents of compressed file using `ZipFile`

# %%
zfobj = ZipFile(outputfile)
zfobj.namelist()
# Out:
# ['austraits-3.0.2/',
#  'austraits-3.0.2/taxa.csv',
#  'austraits-3.0.2/methods.csv',
#  'austraits-3.0.2/definitions.yml',
#  'austraits-3.0.2/build_info.md',
#  'austraits-3.0.2/contributors.csv',
#  'austraits-3.0.2/contexts.csv',
#  'austraits-3.0.2/excluded_data.csv',
#  'austraits-3.0.2/traits.csv',
#  'austraits-3.0.2/taxonomic_updates.csv',
#  'austraits-3.0.2/sites.csv',
#  'austraits-3.0.2/sources.bib']

# %% [markdown]
# ## Next steps
#
# This is it for this step, we can start exploring the austrait data.
